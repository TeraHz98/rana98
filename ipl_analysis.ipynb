# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('matches.csv')
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data=pd.read_csv('matches.csv')

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.head()   #.......it gives preview of data input from start
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.tail() #.....for printing the last 5 rows of the data
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  22-05-2016     Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016        Gujarat Lions
# 633  634    2016      Delhi  25-05-2016  Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016        Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data.size
# Out:
# 11448

# %%
data.shape  #.....return tupple which returns rows and column respectively
# Out:
# (636, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe() #....works only on the data setsthat contains numeric value,
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data[:4] #.......same as that of array
# Out:
#    id  season       city        date                   team1  \
# 0   1    2017  Hyderabad  05-04-2017     Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017          Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017           Gujarat Lions
# 3   4    2017     Indore  08-04-2017  Rising Pune Supergiant
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# ...

# %%
data[::4] #.......same as that of array
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4      5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 8      9    2017           Pune  11-04-2017             Delhi Daredevils
# 12    13    2017         Rajkot  14-04-2017       Rising Pune Supergiant
# 16    17    2017      Bangalore  16-04-2017       Rising Pune Supergiant
# ..   ...     ...            ...         ...                          ...
# 616  617    2016      Bangalore  11-05-2016  Royal Challengers Bangalore
# 620  621    2016        Kolkata  14-05-2016      Rising Pune Supergiants
# 624  625    2016  Visakhapatnam  17-05-2016             Delhi Daredevils
# 628  629    2016  Visakhapatnam  21-05-2016              Kings XI Punjab
# 632  633    2016      Bangalore  24-05-2016                Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data['winner'] #...here writting the column name within the bracket generates that particular column.
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
data[['team1','team2','winner']
# Out:
#   Cell In[20], line 1
#     data[['team1','team2','winner']
#                                    ^
# SyntaxError: incomplete input

# %%
data[['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
data.iloc[0] #........for printing zeroth row
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              05-04-2017
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
data.iloc[0:2:4]
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %%
data.iloc[0:1]
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %%
data[0:1]
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %%
data[1:11:2]
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 5   6    2017  Hyderabad  09-04-2017                Gujarat Lions
# 7   8    2017     Indore  10-04-2017  Royal Challengers Bangalore
# 9  10    2017     Mumbai  12-04-2017          Sunrisers Hyderabad
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 9          Mumbai Indians               Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %%
data.iloc[:,[4:5:10]]
# Out:
#   Cell In[28], line 1
#     data.iloc[:,[4:5:10]]
#                   ^
# SyntaxError: invalid syntax

# %%
data.iloc[:,[4,5,10]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
data=pd.read_csv('matches.csv')

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
mask=data['city']=='Hyderabad'

# %%
mask
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
data[mask]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  09-04-2017                Gujarat Lions
# 18    19    2017  Hyderabad  17-04-2017          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  19-04-2017          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  30-04-2017          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  06-05-2017       Rising Pune Supergiant
# 46    47    2017  Hyderabad  08-05-2017               Mumbai Indians
# 58    59    2017  Hyderabad  21-05-2017               Mumbai Indians
# 65    66    2008  Hyderabad  22-04-2008              Deccan Chargers
# 67    68    2008  Hyderabad  24-04-2008              Deccan Chargers
# 76    77    2008  Hyderabad  01-05-2008              Deccan Chargers
# 79    80    2008  Hyderabad  25-05-2008              Deccan Chargers
# 91    92    2008  Hyderabad  11-05-2008        Kolkata Knight Riders
# ...

# %%
data[mask].shape
# Out:
# (49, 18)

# %%
data[mask].shape[0]
# Out:
# 49

# %%
def get_city_match_count(city):
    mask=data['city']==city
    return data[mask].shape[0]

# %%
get_city_match_count('Kolkata')
# Out:
# 636

# %%
data=pd.read_csv('matches.csv')

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
def get_city_match_count(city):
    mask=data['city']==city
    return data[mask].shape[0]

# %%
get_city_match_count('Kolkata')
# Out:
# 61

# %%
get_city_match_count('Rajkot')
# Out:
# 10

# %%
mask1=data['city']=='Hyderabad'
mask2=data['date']>'29-05-2014'

# %%
data[mask1 & mask2]
# Out:
#       id  season       city        date                team1  \
# 35    36    2017  Hyderabad  30-04-2017  Sunrisers Hyderabad
# 602  603    2016  Hyderabad  30-04-2016  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 35         Kolkata Knight Riders        Kolkata Knight Riders         field
# 602  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#      result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 35   normal           0  Sunrisers Hyderabad           48               0
# 602  normal           0  Sunrisers Hyderabad           15               0
#
#     player_of_match                                      venue       umpire1  \
# 35        DA Warner  Rajiv Gandhi International Stadium, Uppal   AY Dandekar
# 602       DA Warner  Rajiv Gandhi International Stadium, Uppal  AK Chaudhary
#
#              umpire2  umpire3
# 35            S Ravi      NaN
# ...

# %%
data[mask1 & mask2].shape
# Out:
# (2, 18)

# %%
data[mask1 & mask2].shape[0]
# Out:
# 2

# %%
#......value_counts() is the function thats are generally used to count the no. of instances of occurence in series.

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
#.....the pandas plot
import matplotlib.pyplot as plt

# %%
data['winner'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['winner'].value_counts().head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['winner'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
data['win_by_runs'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
myseries=data['winner'].value_counts()

# %%
myseries
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
myseries['Kings XI Punjab']
# Out:
# 70

# %%
#..Q: How to find the total no of MI has played?
#...Caution: We have to take into consideration of both team1 and team 2 because in some matches team1 is MI while in other matches team2 is MI.

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
myseries_t1=data['team1'].value_counts()

# %%
myseries_t1
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
myseries_t2=data['team2'].value_counts()
myseries_t2
# Out:
# Delhi Daredevils               84
# Royal Challengers Bangalore    82
# Kolkata Knight Riders          80
# Mumbai Indians                 75
# Kings XI Punjab                71
# Rajasthan Royals               64
# Chennai Super Kings            54
# Deccan Chargers                32
# Sunrisers Hyderabad            30
# Pune Warriors                  26
# Gujarat Lions                  16
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team2, dtype: int64

# %%
myseries_total=data['team1'].value_counts()+data['team2'].value_counts()
myseries_total
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# dtype: int64

# %%
myseries_sort=(data['team1'].value_counts()+data['team2'].value_counts()).sort_values() 
myseries_sort
#....sorting by default will be in ascending order.
# Out:
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Rising Pune Supergiant          16
# Gujarat Lions                   30
# Pune Warriors                   46
# Deccan Chargers                 75
# Sunrisers Hyderabad             76
# Rajasthan Royals               118
# Chennai Super Kings            131
# Delhi Daredevils               147
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Royal Challengers Bangalore    152
# Mumbai Indians                 157
# dtype: int64

# %%
myseries_sortd=(data['team1'].value_counts()+data['team2'].value_counts()).sort_values(ascending=False) 
myseries_sortd
#....sorting by default will be in ascending order.
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
data.sort_values('city')
# Out:
#       id  season       city        date                        team1  \
# 460  461    2014  Abu Dhabi  18-04-2014          Sunrisers Hyderabad
# 471  472    2014  Abu Dhabi  26-04-2014              Kings XI Punjab
# 470  471    2014  Abu Dhabi  26-04-2014  Royal Challengers Bangalore
# 464  465    2014  Abu Dhabi  21-04-2014          Chennai Super Kings
# 459  460    2014  Abu Dhabi  18-04-2014          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  23-04-2014          Chennai Super Kings
# 468  469    2014        NaN  25-04-2014          Sunrisers Hyderabad
# 469  470    2014        NaN  25-04-2014               Mumbai Indians
# 474  475    2014        NaN  28-04-2014  Royal Challengers Bangalore
# 476  477    2014        NaN  30-04-2014          Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
data.sort_values('city',ascending=False)
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  07-04-2012          Chennai Super Kings
# 622  623    2016  Visakhapatnam  15-05-2016               Mumbai Indians
# 615  616    2016  Visakhapatnam  10-05-2016          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  08-05-2016          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  17-05-2016             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  23-04-2014          Chennai Super Kings
# 468  469    2014            NaN  25-04-2014          Sunrisers Hyderabad
# 469  470    2014            NaN  25-04-2014               Mumbai Indians
# 474  475    2014            NaN  28-04-2014  Royal Challengers Bangalore
# 476  477    2014            NaN  30-04-2014          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
data.sort_values(['city','date'])
# Out:
#       id  season       city        date                        team1  \
# 457  458    2014  Abu Dhabi  16-04-2014        Kolkata Knight Riders
# 459  460    2014  Abu Dhabi  18-04-2014          Chennai Super Kings
# 460  461    2014  Abu Dhabi  18-04-2014          Sunrisers Hyderabad
# 464  465    2014  Abu Dhabi  21-04-2014          Chennai Super Kings
# 470  471    2014  Abu Dhabi  26-04-2014  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  23-04-2014          Chennai Super Kings
# 468  469    2014        NaN  25-04-2014          Sunrisers Hyderabad
# 469  470    2014        NaN  25-04-2014               Mumbai Indians
# 474  475    2014        NaN  28-04-2014  Royal Challengers Bangalore
# 476  477    2014        NaN  30-04-2014          Sunrisers Hyderabad
#
#                    team2            toss_winner toss_decision  result  \
# ...

# %%
data.sort_values(['city','date'],ascending=False)
# Out:
#       id  season           city        date                  team1  \
# 536  537    2015  Visakhapatnam  22-04-2015    Sunrisers Hyderabad
# 628  629    2016  Visakhapatnam  21-05-2016        Kings XI Punjab
# 530  531    2015  Visakhapatnam  18-04-2015       Delhi Daredevils
# 624  625    2016  Visakhapatnam  17-05-2016       Delhi Daredevils
# 528  529    2015  Visakhapatnam  16-04-2015    Sunrisers Hyderabad
# ..   ...     ...            ...         ...                    ...
# 468  469    2014            NaN  25-04-2014    Sunrisers Hyderabad
# 469  470    2014            NaN  25-04-2014         Mumbai Indians
# 466  467    2014            NaN  23-04-2014    Chennai Super Kings
# 461  462    2014            NaN  19-04-2014         Mumbai Indians
# 462  463    2014            NaN  19-04-2014  Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# 536        Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
data.drop_duplicates(subset=['city'])
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017            Pune  06-04-2017               Mumbai Indians
# 2      3    2017          Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017          Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017       Bangalore  08-04-2017  Royal Challengers Bangalore
# 6      7    2017          Mumbai  09-04-2017        Kolkata Knight Riders
# 10    11    2017         Kolkata  13-04-2017              Kings XI Punjab
# 14    15    2017           Delhi  15-04-2017             Delhi Daredevils
# 31    32    2017      Chandigarh  28-04-2017          Sunrisers Hyderabad
# 48    49    2017          Kanpur  10-05-2017                Gujarat Lions
# 64    65    2008          Jaipur  21-04-2008              Kings XI Punjab
# 66    67    2008         Chennai  23-04-2008          Chennai Super Kings
# ...

# %%
data.drop_duplicates(subset=['city']).shape
# Out:
# (31, 18)

# %%
#..that means over the years ipl has been played over 31 unique cities.

# %%
data.drop_duplicates(subset=['city','season']).shape
# Out:
# (107, 18)

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data['date'].sort_values()
# Out:
# 203    01-04-2010
# 76     01-05-2008
# 77     01-05-2008
# 137    01-05-2009
# 138    01-05-2009
#           ...
# 114    30-05-2008
# 515    30-05-2014
# 202    31-03-2010
# 201    31-03-2010
# 115    31-05-2008
# Name: date, Length: 636, dtype: object

# %%
data.sort_values(['season','date'])
# Out:
#       id  season        city        date                   team1  \
# 76    77    2008   Hyderabad  01-05-2008         Deccan Chargers
# 77    78    2008      Jaipur  01-05-2008        Rajasthan Royals
# 116  117    2008      Mumbai  01-06-2008     Chennai Super Kings
# 78    79    2008     Chennai  02-05-2008     Chennai Super Kings
# 80    81    2008  Chandigarh  03-05-2008         Kings XI Punjab
# ..   ...     ...         ...         ...                     ...
# 31    32    2017  Chandigarh  28-04-2017     Sunrisers Hyderabad
# 32    33    2017        Pune  29-04-2017  Rising Pune Supergiant
# 33    34    2017      Rajkot  29-04-2017           Gujarat Lions
# 34    35    2017  Chandigarh  30-04-2017        Delhi Daredevils
# 35    36    2017   Hyderabad  30-04-2017     Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 76               Kings XI Punjab              Kings XI Punjab         field
# ...

# %%
# sorting dates predominantly does it with respect to day.Beware

# %%
data.drop_duplicates(['season']).sort_values(['season'])
# Out:
#       id  season       city        date                  team1  \
# 59    60    2008  Bangalore  18-04-2008  Kolkata Knight Riders
# 117  118    2009  Cape Town  18-04-2009         Mumbai Indians
# 174  175    2010     Mumbai  12-03-2010  Kolkata Knight Riders
# 234  235    2011    Chennai  08-04-2011    Chennai Super Kings
# 307  308    2012    Chennai  04-04-2012    Chennai Super Kings
# 381  382    2013    Kolkata  03-04-2013       Delhi Daredevils
# 457  458    2014  Abu Dhabi  16-04-2014  Kolkata Knight Riders
# 517  518    2015    Kolkata  08-04-2015         Mumbai Indians
# 576  577    2016     Mumbai  09-04-2016         Mumbai Indians
# 0      1    2017  Hyderabad  05-04-2017    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 117          Chennai Super Kings          Chennai Super Kings         field
# ...

# %%
data.drop_duplicates(['season'],keep='last').sort_values(['season'])
# Out:
#       id  season          city        date                team1  \
# 116  117    2008        Mumbai  01-06-2008  Chennai Super Kings
# 173  174    2009  Johannesburg  24-05-2009      Deccan Chargers
# 233  234    2010        Mumbai  25-04-2010  Chennai Super Kings
# 306  307    2011       Chennai  28-05-2011  Chennai Super Kings
# 380  381    2012       Chennai  27-05-2012  Chennai Super Kings
# 456  457    2013       Kolkata  26-05-2013       Mumbai Indians
# 516  517    2014     Bangalore  01-06-2014      Kings XI Punjab
# 575  576    2015       Kolkata  24-05-2015       Mumbai Indians
# 635  636    2016     Bangalore  29-05-2016  Sunrisers Hyderabad
# 58    59    2017     Hyderabad  21-05-2017       Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 116             Rajasthan Royals             Rajasthan Royals         field
# 173  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
#......drop duplicates is a tricky question

# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('matches.csv')
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data=pd.read_csv('matches.csv')

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.drop_duplicates(['season'],keep='last').sort_values(['season'])[['season','winner']]
#....[['season','winner']] this will be within square brackets
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %%
sectors=data.groupby('toss_winner')

# %%
len(data)
# Out:
# 636

# %%
data2=pd.read_csv('delivery.csv')

# %%
data2
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
runs= data2.groupby('batsman')

# %%
runs.get_group('V Kohli')
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 2590          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2591          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2593          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2594          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2597          12       1  Royal Challengers Bangalore       Mumbai Indians
# ...          ...     ...                          ...                  ...
# 150410       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150413       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150414       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150415       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150416       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
runs.get_group('V Kohli').shape
# Out:
# (3494, 21)

# %%
#......virat has faced 3494 balls in his carrier

# %%
runs['batsman_runs'].sum()
# Out:
# batsman
# A Ashish Reddy     280
# A Chandila           4
# A Chopra            53
# A Choudhary         25
# A Flintoff          62
#                   ...
# YV Takawale        192
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2591
# Z Khan             117
# Name: batsman_runs, Length: 461, dtype: int64

# %%
runs['batsman_runs'].sum().sort_values()
# Out:
# batsman
# S Kaushik            0
# S Ladda              0
# V Pratap Singh       0
# L Ablish             0
# IC Pandey            0
#                   ...
# DA Warner         4014
# G Gambhir         4132
# RG Sharma         4207
# V Kohli           4423
# SK Raina          4548
# Name: batsman_runs, Length: 461, dtype: int64

# %%
runs['batsman_runs'].sum().sort_values(ascending=False)
# Out:
# batsman
# SK Raina        4548
# V Kohli         4423
# RG Sharma       4207
# G Gambhir       4132
# DA Warner       4014
#                 ...
# Abdur Razzak       0
# S Kaushik          0
# S Ladda            0
# U Kaul             0
# RR Bhatkal         0
# Name: batsman_runs, Length: 461, dtype: int64

# %%
match=pd.read_csv('matches.csv')

# %% [markdown]
# match

# %%
match
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
deliveries=pd.read_csv('delivery.csv')
deliveries
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
mask=deliveries['total_runs']==6
six= deliveries[mask]
six.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mask=deliveries['total_runs']==6
#       2 six= deliveries[mask]
#       3 six.head()
#
# NameError: name 'deliveries' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
graph=deliveries[mask].plot(kind='bar')
graph
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 graph=deliveries[mask].plot(kind='bar')
#       2 graph
#
# NameError: name 'deliveries' is not defined

# %%
match=pd.read_csv('matches.csv')
match
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
deliveries=pd.read_csv('delivery.csv')
deliveries
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
mask=deliveries['total_runs']==6
six= deliveries[mask]
six.head()
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 47         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     8
# 75         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    13
# 89         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    15
# 91         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    15
#
#     ball       batsman   non_striker       bowler  is_super_over  ...  \
# 10     4     DA Warner      S Dhawan  A Choudhary              0  ...
# 47     4  MC Henriques      S Dhawan      TM Head              0  ...
# 75     2  Yuvraj Singh  MC Henriques  A Choudhary              0  ...
# 89     3  Yuvraj Singh  MC Henriques    S Aravind              0  ...
# 91     5  MC Henriques  Yuvraj Singh    S Aravind              0  ...
#
#     bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %%
graph= deliveries[mask].head().plot(kind='barh')
graph
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
graph= deliveries[mask].head().plot(kind='bar')
graph
# Out:
# <AxesSubplot:>

# %%
six.pivot_table(index='over',columns='batting_team',values='batsman_runs',aggfunc='count')
# Out:
# batting_team  Chennai Super Kings  Deccan Chargers  Delhi Daredevils  \
# over
# 1                             5.0              3.0              14.0
# 2                            17.0             21.0              19.0
# 3                            37.0             11.0              30.0
# 4                            34.0             17.0              41.0
# 5                            41.0             27.0              29.0
# 6                            43.0             22.0              27.0
# 7                            22.0             11.0              19.0
# 8                            25.0             13.0              26.0
# 9                            23.0             17.0              32.0
# 10                           23.0             14.0              24.0
# 11                           36.0             15.0              34.0
# 12                           36.0             26.0              38.0
# ...
